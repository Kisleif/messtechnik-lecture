# %% [markdown]
# ---
# Zurück zur Übersicht | [Inhalt](00_Inhalt.ipynb)
#
# ---

# %%
# Für diese Notebook benötigte Pakete:
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# # Messen elektrischer Größen

# %% [markdown]
# ## Inhalt
# ***
#
# ### [Spannungsmesseingang](#Sec-Spannungsmesseingang)
# * [Messeingang mit Gleichspannung](#SubSec-Messeingang_mit_Gleichspannung)
# * [Messeingang mit Wechselspannung](#SubSec-Messeingang_mit_Wechselspannung)
# * [Grobe Struktur](#SubSec-Grobe_Struktur)
# * [Beispiel: Messung des Gleichrichtwerts](#SubSec-Beispiel_gleichrichtwert)
#
# ### [Strommesseingang](#Sec-Strommesseingang)
# * [Strommessung](#SubSec-Strommessung)
# * [Messwerke](#SubSec-Messverstärker)
#
# ### [Messverstärker](#Sec-Messverstärker)
# * [Operationsverstärkerschaltungen](#SubSec-Operationsverstärkerschaltungen)
#
#
# ### [Leistungsmessung](#Sec-Leistungsmessung)
# * [Stromrichtige und Spannungsrichtige Anschaltung](#SubSec-Anschaltung_Leistung)
# * [Leistungsmessung in Wechselstromsystemen](#SubSec-Leistungsmessung_in_Wechselstromsystemen)
# * [Leistungsmessung in Drehstromsystem](#SubSec-Leistungsmessung_in_Drehstromsystem)
#
# ### [Widerstandsmessung](#Sec-Widerstandsmessung)
# * [Stromrichtige und Spannungsrichtige Anschaltung](#SubSec-Anschaltung_Widerstand)
# * [Systematischer Fehler durch Kabelwiderstände](#SubSec-Kabelwiderstand)
# * [Brückenschaltung](#SubSec-Brückenschaltung)
#
# ### [Frequenzmessung](#Sec-Frequenzmessung)
#
# ### [Zusammenfassung](#Sec-Zusammenfassung)
#
#
# ***

# %% [markdown]
# ## Spannungsmesseingang
# <a id="Sec-Spannungsmesseingang"></a>
#
# ### Messeingang mit Gleichspannung
# <a id="SubSec-Messeingang_mit_Gleichspannung"></a>
#
# ### Messeingang mit Wechselspannung
# <a id="SubSec-Messeingang_mit_Wechselspannung"></a>
#
# ### Grobe Struktur
# <a id="SubSec-Grobe_Struktur"></a>
#
# ### Beispiel: Messung des Gleichrichtwerts
# <a id="SubSec-Beispiel_gleichrichtwert"></a>

# %% [markdown]
# ## Strommesseingang
# <a id="Sec-Strommesseingang"></a>
#
# ### Strommessung
# <a id="SubSec-Strommessung"></a>
#
# ### Messwerke
# <a id="SubSec-Messverstärker"></a>

# %% [markdown]
# ## Messverstärker
# <a id="Sec-Messverstärker"></a>
#
# ### Operationsverstärkerschaltungen
# <a id="SubSec-Operationsverstärkerschaltungen"></a>

# %% [markdown]
# ## Leistungsmessung
# <a id="Sec-Leistungsmessung"></a>
#
# ### Stromrichtige und Spannungsrichtige Anschaltung
# <a id="SubSec-Anschaltung_Leistung"></a>
#
# ### Leistungsmessung in Wechselstromsystemen
# <a id="SubSec-Leistungsmessung_in_Wechselstromsystemen"></a>
#
# ### Leistungsmessung in Drehstromsystem
# <a id="SubSec-Leistungsmessung_in_Drehstromsystem"></a>

# %% [markdown]
# ## Widerstandsmessung
# <a id="Sec-Widerstandsmessung"></a>
#
# ### Stromrichtige und Spannungsrichtige Anschaltung
# <a id="SubSec-Anschaltung_Widerstand"></a>
#
# ### Systematischer Fehler durch Kabelwiderstände
# <a id="SubSec-Kabelwiderstand"></a>
#
# ### Brückenschaltung
# <a id="SubSec-Brückenschaltung"></a>

# %% [markdown]
# ## Frequenzmessung
# <a id="Sec-Frequenzmessung"></a>

# %% [markdown]
# ## Zusammenfassung
# <a id="Sec-Zusammenfassung"></a>

# %%
Image("pictures/zusammenfassung_7.png", width=800)
